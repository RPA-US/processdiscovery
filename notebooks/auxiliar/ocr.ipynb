# %%
import keras_ocr
import pandas as pd
import os

# %%
df = pd.read_csv('logs\invoice_def\log.csv', sep=';')
img_names = df['screenshot'].values

# %%
pipeline = keras_ocr.pipeline.Pipeline()
for img in img_names:
    ocr_result = get_ocr_image(pipeline,'resources\invoice_def', img)
# Out:
# Looking for C:\Users\ES3-PORT-41\.keras-ocr\craft_mlt_25k.h5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 4
#       1 import keras_ocr
#       3 # Cargar el detector y el reconocedor pre-entrenados de keras-ocr
# ----> 4 pipeline = keras_ocr.pipeline.Pipeline()
#       6 # Ruta a la imagen o imágenes
#       7 # Puedes usar una lista de rutas si tienes múltiples
#       9 paths = ['logs\invoice_def\1_img.png']
#
# File c:\Users\ES3-PORT-41\Documents\GitProjects\processdiscovery\.venv\lib\site-packages\keras_ocr\pipeline.py:22, in Pipeline.__init__(self, detector, recognizer, scale, max_size)
#      20     detector = detection.Detector()
#      21 if recognizer is None:
# ---> 22     recognizer = recognition.Recognizer()
#      23 self.scale = scale
#      24 self.detector = detector
#
# ...
